# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn
import seaborn as sn
import datetime
import random
from datetime import date
from pprint import pprint
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import statistics 
from statistics import mode

# %%
def aggregate_rows_by_driver_id(dataframe):
    '''
    Returns a new dataframe indexed by Driver ID using an optimal set of aggregations per column.
    This method will return a dataframe that only contains the columns listed below.
    Note: duplicate columns have already been pruned, so it is safe to pass in the full dataframe 
        and expect a pruned version in return. Also note that the `id_driver` will now be the index
        of the dataframe and NOT its own column.
    '''
    minimum = 'min'
    maximum = 'max'
    median = 'median'
    
    # In certain cases, the mode is actually more than one value (i.e. [2, 3] will have a mode of [2, 3].
    # The normal `mode` function will return the smallest value in a list, but returning random is better.
    random_mode = lambda x: random.choice(pd.Series.mode(x if isinstance(x, list) else list(x)))

    aggregation = {
        'dt': maximum,
        'weekday': random_mode,
        'id_carrier_number': random_mode,
        'dim_carrier_type': random_mode,
        'dim_carrier_company_name': mode,
        'home_base_city': mode,
        'home_base_state': mode,
        'carrier_trucks': mode,
        'num_trucks': maximum,
        'interested_in_drayage': random_mode,
        'port_qualified': random_mode,
        'signup_source': random_mode,
        'ts_signup': maximum,
        'ts_first_approved': minimum,
        'days_signup_to_approval': maximum,
        'driver_with_twic': mode,
        'dim_preferred_lanes': mode,
        'first_load_date': minimum,
        'most_recent_load_date': maximum,
        'loads': random_mode,
        'marketplace_loads_otr': maximum,
        'marketplace_loads_atlas': maximum,
        'marketplace_loads': maximum,
        'brokerage_loads_otr': maximum,
        'brokerage_loads_atlas': maximum,
        'brokerage_loads': maximum,
        'total_loads': maximum
    }

    return dataframe.groupby(['id_driver']).agg(aggregation)

# %%
df = pd.read_csv('training_dataset_V3.csv')
df.shape
# Out:
# (83414, 31)

# %% [markdown]
# # Data Inspection

# %%
df
# Out:
#        Unnamed: 0          dt  weekday  year  id_driver id_carrier_number  \
# 0               0  2021-01-20        3  2021      30222          U0117613
# 1               1  2020-03-09        1  2020       4524          C0090405
# 2               2  2020-02-14        5  2020      31164          C0097099
# 3               3  2019-06-10        1  2019       8859          U0097935
# 4               4  2019-12-03        2  2019      18870          U0106560
# ...           ...         ...      ...   ...        ...               ...
# 83409       83409  2020-11-09        1  2020      26609          C0095984
# 83410       83410  2018-10-30        2  2018        595          C0090094
# 83411       83411  2020-07-14        2  2020      34520          C0094651
# 83412       83412  2021-01-06        3  2021      34253          C0095226
# 83413       83413  2019-07-29        1  2019       4739          U0094383
#
#       dim_carrier_type            dim_carrier_company_name    home_base_city  \
# 0       Owner Operator                     Rosas Transport  Santa Fe Springs
# 1                Fleet                  Daylight Transport        Long Beach
# 2                Fleet            First Class Transport #8         Hawthorne
# 3       Owner Operator                    DTELLIS TRUCKING        Long Beach
# 4       Owner Operator                       Z&N Transport       Los Angeles
# ...                ...                                 ...               ...
# 83409            Fleet  WESTERN CONTAIN TRANSPORTATION LLC       Los Angeles
# 83410            Fleet             MC Express Trucking LLC          Rosarito
# 83411            Fleet                   NFS asset Drayage           Lynwood
# 83412            Fleet            INTERMODAL DRAYAGE GROUP    San Bernardino
# 83413   Owner Operator                       ayon trucking           Lynwood
#
#       home_base_state  ... loads  marketplace_loads_otr  \
# 0                  CA  ...     4                      1
# 1                  CA  ...     6                      0
# 2                  CA  ...     1                     29
# 3                  CA  ...     1                     25
# 4                  CA  ...     4                      1
# ...               ...  ...   ...                    ...
# 83409              CA  ...     3                      2
# 83410            B.C.  ...     1                      0
# 83411              CA  ...     2                      0
# 83412              CA  ...     1                      8
# 83413              CA  ...     1                      0
#
#       marketplace_loads_atlas marketplace_loads brokerage_loads_otr  \
# 0                         253               254                   0
# 1                           0                 0                2671
# 2                          82               111                  30
# 3                           6                31                   0
# 4                         233               234                   0
# ...                       ...               ...                 ...
# 83409                     895               897                   0
# 83410                       0                 0                  77
# 83411                       0                 0                   0
# 83412                       2                10                   0
# 83413                       1                 1                 293
#
#       brokerage_loads_atlas brokerage_loads  total_loads        date  \
# 0                         3               3          257  2021-01-20
# 1                         0            2671         2671  2020-03-09
# 2                        19              49          160  2020-02-14
# 3                         1               1           32  2019-06-10
# 4                         9               9          243  2019-12-03
# ...                     ...             ...          ...         ...
# 83409                    93              93          990  2020-11-09
# 83410                     0              77           77  2018-10-30
# 83411                     0               0          101  2020-07-14
# 83412                     0               0           10  2021-01-06
# 83413                     0             293          294  2019-07-29
#
#       recent_date
# 0      2021-02-17
# 1      2021-02-15
# 2      2020-12-18
# 3      2020-02-16
# 4      2020-02-18
# ...           ...
# 83409  2021-02-16
# 83410  2019-11-06
# 83411  2021-02-17
# 83412  2021-01-16
# 83413  2019-09-19
#
# [83414 rows x 33 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83414 entries, 0 to 83413
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                83414 non-null  int64
#  1   dt                        83414 non-null  object
#  2   weekday                   83414 non-null  object
#  3   year                      83414 non-null  int64
#  4   id_driver                 83414 non-null  int64
#  5   id_carrier_number         83414 non-null  object
#  6   dim_carrier_type          83414 non-null  object
#  7   dim_carrier_company_name  83365 non-null  object
#  8   home_base_city            83369 non-null  object
#  9   home_base_state           83369 non-null  object
#  10  carrier_trucks            83414 non-null  object
#  11  num_trucks                83344 non-null  float64
#  12  interested_in_drayage     83414 non-null  object
#  13  port_qualified            83414 non-null  object
#  14  signup_source             83414 non-null  object
#  15  ts_signup                 83414 non-null  object
#  16  ts_first_approved         71124 non-null  object
#  17  days_signup_to_approval   71124 non-null  float64
#  18  driver_with_twic          83414 non-null  object
#  19  dim_preferred_lanes       3412 non-null   object
#  20  first_load_date           83414 non-null  object
#  21  most_recent_load_date     83414 non-null  object
#  22  load_day                  83414 non-null  object
#  23  loads                     83414 non-null  int64
#  24  marketplace_loads_otr     83414 non-null  int64
#  25  marketplace_loads_atlas   83414 non-null  int64
#  26  marketplace_loads         83414 non-null  int64
#  27  brokerage_loads_otr       83414 non-null  int64
#  28  brokerage_loads_atlas     83414 non-null  int64
#  29  brokerage_loads           83414 non-null  int64
#  30  total_loads               83414 non-null  int64
# dtypes: float64(2), int64(11), object(18)
# memory usage: 19.7+ MB

# %%
df.nunique()
# Out:
# dt                          1907
# weekday                        7
# id_driver                   5291
# id_carrier_number           2573
# dim_carrier_type               2
# dim_carrier_company_name    2491
# home_base_city               520
# home_base_state               40
# carrier_trucks                16
# num_trucks                    30
# interested_in_drayage          2
# port_qualified                 2
# signup_source                  2
# ts_signup                   2573
# ts_first_approved           1880
# days_signup_to_approval      674
# driver_with_twic               2
# dim_preferred_lanes           53
# first_load_date             1458
# most_recent_load_date       1418
# loads                         67
# marketplace_loads_otr        108
# marketplace_loads_atlas      196
# marketplace_loads            228
# brokerage_loads_otr          216
# brokerage_loads_atlas        101
# brokerage_loads              241
# total_loads                  331
# dtype: int64

# %%
plt.figure(figsize=(14,9))
sn.heatmap(df.corr(), annot=True)
plt.show()

# %% [markdown]
# # Check for and Remove Duplicate Columns

# %%
df = pd.read_csv('training_dataset_V3.csv')
df.shape
# Out:
# (83414, 31)

# %%
for (columnName1, columnData1) in df.iteritems():
    for (columnName2, columnData2) in df.iteritems():
        if columnData1.equals(columnData2) and columnName1 is not columnName2:
            print(f'{columnName1} is equal to {columnName2}')
# Out:
# dt is equal to load_day
# load_day is equal to dt

# %% [markdown]
# # Data Cleanup and Convenience
#
# Drop `unnamed` since it is just a row count.
#
# Drop the `year` column since it is redundant and already included in the `dt` column.
#
# Drop the `load_day` column since is the same as the `dt` column.
#
# Convert the `dt` and `most_recent_load_date` columns to `datetime.date` objects for convenience.

# %%
toRemove = ['Unnamed: 0', 'year', 'load_day']
df.drop(columns=toRemove, inplace=True)
df.dt = [date.fromisoformat(d) for d in df.dt]
df.most_recent_load_date = [date.fromisoformat(d) for d in df.most_recent_load_date]

# %%
categoricals = df.columns[df.dtypes == object]
numericals = df.columns[df.dtypes != object]
n_drivers = df.id_driver.nunique()
driver_ids = sorted(df.id_driver.unique())

# %%
df.shape
# Out:
# (83414, 28)

# %% [markdown]
# # Augmentation Methodology
# The following describes the methodology used to augment all of the driver information given that we are going to collapse the data into a frame with single rows per driver. Since we will be inherently losing information by collapsing all of the rows, we will need to supplement the dataset with new columns.
#
# ## Temporal Data
# Most of the temporal information will be lost when we collapse the rows, so we will need additional columns that summarize that info:
#
# - Start date (first load)
# - End date (most recent load)
# - Longevity (how long the driver has been employed, according to this dataset)
# - Trip Frequency (standard deviation or some measure of variance between trips)
# - Load Delta (some standard measure of how many days between each load)
# - Preferred weekday (the mode of the `weekday` column
# - Normal weekday (the mean or median of the `weekday` column
# - Weekday distribution (are the weekdays consistent?)
#
# ## Location Data
#
# - Roaming (does the driver have more than one reported `home_base_city` or `home_base_state`?
# - Preferred Trip Distance (Use `interested_in_dryage` and `carrier_trucks` to determine a measure of how far the driver prefers to drive)
#
# ## Boolean Features
#
# - Multiple signup dates (did this person apply to become a driver more than once?)
#
# ---
#
# # Transformation Methodology
#
# ## Converting categoricals to boolean
#
# The following columns have only two unique values, which are easily turned into boolean features:
#
# - dim_carrier_type (corresponds to "is this a self-owned driver?", **0: Fleet, 1: Owner Operator**)
# - interested_in_drayage (corresponds to "is this driver willing/able to complete drayage shipments?", **0: not specified, 1: yes**)
# - port_qualified (corresponds to "is this driver qualified to handle port shipments?", **0: no, 1: yes**)
# - signup_source (corresponds to "did this driver sign up on a mobile device?", **0: Other, 1: Mobile**)
# - driver_with_twic (corresponds to "does this driver have TWIC insurance?" **0: no, 1: yes**)
#
# ## One Hot Encoding Categoricals
#
# The following columns have a limited number of unique categorical values that would work well with one-hot encoding
#
# -

# %% [markdown]
# `id_driver`: Used as an index. All of the information will be rolled up into a single row for each driver.

# %%
drivers = pd.DataFrame()
drivers['id_driver'] = driver_ids
drivers.set_index('id_driver', inplace=True)

# %%
drivers.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [20, 26, 27, 30, 31]

# %% [markdown]
# ---
#
# `dt`: three columns: earliest, latest, and longevity

# %%
drivers['dt_earliest'] = df.groupby('id_driver').dt.min()
drivers['dt_latest'] = df.groupby('id_driver').dt.max()
drivers['longevity'] = [t.days + 1 for t in drivers.dt_latest - drivers.dt_earliest]

# %%
drivers.head()
# Out:
#           dt_earliest   dt_latest  longevity
# id_driver
# 20         2015-10-23  2016-06-20        242
# 26         2015-10-29  2015-10-29          1
# 27         2015-10-18  2015-12-09         53
# 30         2018-10-30  2018-12-05         37
# 31         2016-02-28  2016-04-01         34

# %% [markdown]
# ---
#
# `weekday (mon, wed, etc)`: most frequent weekday

# %%
drivers['weekday'] = df.groupby('id_driver').weekday.agg(pd.Series.mode)

# %%
drivers.head()
# Out:
#           dt_earliest   dt_latest  longevity weekday
# id_driver
# 20         2015-10-23  2016-06-20        242       4
# 26         2015-10-29  2015-10-29          1       4
# 27         2015-10-18  2015-12-09         53       3
# 30         2018-10-30  2018-12-05         37       3
# 31         2016-02-28  2016-04-01         34       2

# %% [markdown]
# ---
#
# `dim_carrier_type`: Redundant, already included in `id_carrier_number`, which starts with a `U` if `Onwer Operator` and a `C` if `Fleet`

# %% [markdown]
# `id_carrier_number`: Encode a new boolean column (called `owner_operator`) that is 0 if `Fleet` or 1 if `Owner Operator`

# %%
self_owned = sorted(df.id_driver[df.id_carrier_number.str.slice(start=0, stop=1) == 'U'].unique())

# %%
drivers['self_owned'] = False
drivers['self_owned'] = label_encoder.fit_transform(drivers.index.isin(self_owned))

# %%
drivers.self_owned.value_counts()
# Out:
# 0    4083
# 1    1205
# Name: self_owned, dtype: int64

# %% [markdown]
# ---

# %%
drivers['carrier_trucks'] = df.groupby('id_driver').carrier_trucks.agg(pd.Series.mode)
drivers
# Out:
#           dt_earliest   dt_latest  longevity    weekday  self_owned  \
# id_driver
# 20         2015-10-23  2016-06-20        242          4           1
# 26         2015-10-29  2015-10-29          1          4           1
# 27         2015-10-18  2015-12-09         53          3           1
# 30         2018-10-30  2018-12-05         37          3           1
# 31         2016-02-28  2016-04-01         34          2           1
# ...               ...         ...        ...        ...         ...
# 37977      2021-02-11  2021-02-11          1          4           0
# 38039      2021-02-16  2021-02-16          1          2           0
# 38060      2021-02-12  2021-02-13          2     [5, 6]           0
# 38065      2021-02-15  2021-02-17          3  [1, 2, 3]           0
# 38096      2021-02-12  2021-02-12          1          5           0
#
#                       carrier_trucks
# id_driver
# 20                        ["dryvan"]
# 26                        ["dryvan"]
# 27                        ["dryvan"]
# 30                        ["reefer"]
# 31                        ["dryvan"]
# ...                              ...
# 37977                  ["poweronly"]
# 38039                     ["dryvan"]
# 38060        ["poweronly", "dryvan"]
# 38065        ["poweronly", "dryvan"]
# 38096      ["poweronly", "boxtruck"]
#
# [5288 rows x 6 columns]

# %% [markdown]
# ---

# %%
drivers['driver_home_base_state'] = df.groupby('id_driver').home_base_state.agg(pd.Series.mode)
drivers
# Out:
#           dt_earliest   dt_latest  longevity    weekday  self_owned  \
# id_driver
# 20         2015-10-23  2016-06-20        242          4           1
# 26         2015-10-29  2015-10-29          1          4           1
# 27         2015-10-18  2015-12-09         53          3           1
# 30         2018-10-30  2018-12-05         37          3           1
# 31         2016-02-28  2016-04-01         34          2           1
# ...               ...         ...        ...        ...         ...
# 37977      2021-02-11  2021-02-11          1          4           0
# 38039      2021-02-16  2021-02-16          1          2           0
# 38060      2021-02-12  2021-02-13          2     [5, 6]           0
# 38065      2021-02-15  2021-02-17          3  [1, 2, 3]           0
# 38096      2021-02-12  2021-02-12          1          5           0
#
#                       carrier_trucks driver_home_base_state
# id_driver
# 20                        ["dryvan"]                     CA
# 26                        ["dryvan"]                     CA
# 27                        ["dryvan"]                     CA
# 30                        ["reefer"]                     CA
# 31                        ["dryvan"]                     []
# ...                              ...                    ...
# 37977                  ["poweronly"]                     CA
# 38039                     ["dryvan"]                     CA
# 38060        ["poweronly", "dryvan"]                     CA
# 38065        ["poweronly", "dryvan"]                     CA
# 38096      ["poweronly", "boxtruck"]                     CA
#
# [5288 rows x 7 columns]

# %%
driver_port_qualified = df.groupby('id_driver').port_qualified.agg(pd.Series.mode)
label_encoder.fit(['no', 'yes'])
drivers['port_qualified'] = label_encoder.transform(driver_port_qualified)
drivers
# Out:
#           dt_earliest   dt_latest  longevity    weekday  self_owned  \
# id_driver
# 20         2015-10-23  2016-06-20        242          4           1
# 26         2015-10-29  2015-10-29          1          4           1
# 27         2015-10-18  2015-12-09         53          3           1
# 30         2018-10-30  2018-12-05         37          3           1
# 31         2016-02-28  2016-04-01         34          2           1
# ...               ...         ...        ...        ...         ...
# 37977      2021-02-11  2021-02-11          1          4           0
# 38039      2021-02-16  2021-02-16          1          2           0
# 38060      2021-02-12  2021-02-13          2     [5, 6]           0
# 38065      2021-02-15  2021-02-17          3  [1, 2, 3]           0
# 38096      2021-02-12  2021-02-12          1          5           0
#
#                       carrier_trucks driver_home_base_state  port_qualified
# id_driver
# 20                        ["dryvan"]                     CA               0
# 26                        ["dryvan"]                     CA               0
# 27                        ["dryvan"]                     CA               0
# 30                        ["reefer"]                     CA               0
# 31                        ["dryvan"]                     []               0
# ...                              ...                    ...             ...
# 37977                  ["poweronly"]                     CA               1
# 38039                     ["dryvan"]                     CA               0
# 38060        ["poweronly", "dryvan"]                     CA               1
# 38065        ["poweronly", "dryvan"]                     CA               1
# 38096      ["poweronly", "boxtruck"]                     CA               1
#
# [5288 rows x 8 columns]

# %% [markdown]
# ---

# %%
interested_in_drayage = df.groupby('id_driver').interested_in_drayage.agg(pd.Series.mode)
interested_in_dryage = interested_in_drayage == 'yes'
drivers['interested_in_dryage'] = label_encoder.fit_transform(interested_in_dryage)
drivers
# Out:
#           dt_earliest   dt_latest  longevity    weekday  self_owned  \
# id_driver
# 20         2015-10-23  2016-06-20        242          4           1
# 26         2015-10-29  2015-10-29          1          4           1
# 27         2015-10-18  2015-12-09         53          3           1
# 30         2018-10-30  2018-12-05         37          3           1
# 31         2016-02-28  2016-04-01         34          2           1
# ...               ...         ...        ...        ...         ...
# 37977      2021-02-11  2021-02-11          1          4           0
# 38039      2021-02-16  2021-02-16          1          2           0
# 38060      2021-02-12  2021-02-13          2     [5, 6]           0
# 38065      2021-02-15  2021-02-17          3  [1, 2, 3]           0
# 38096      2021-02-12  2021-02-12          1          5           0
#
#                       carrier_trucks driver_home_base_state  port_qualified  \
# id_driver
# 20                        ["dryvan"]                     CA               0
# 26                        ["dryvan"]                     CA               0
# 27                        ["dryvan"]                     CA               0
# 30                        ["reefer"]                     CA               0
# 31                        ["dryvan"]                     []               0
# ...                              ...                    ...             ...
# 37977                  ["poweronly"]                     CA               1
# 38039                     ["dryvan"]                     CA               0
# 38060        ["poweronly", "dryvan"]                     CA               1
# 38065        ["poweronly", "dryvan"]                     CA               1
# 38096      ["poweronly", "boxtruck"]                     CA               1
#
#            interested_in_dryage
# id_driver
# 20                            0
# 26                            0
# 27                            0
# 30                            0
# 31                            0
# ...                         ...
# 37977                         1
# 38039                         0
# 38060                         1
# 38065                         1
# 38096                         1
#
# [5288 rows x 9 columns]

# %%
pd.get_dummies(df.signup_source)
# Out:
#        Mobile  Other
# 0           1      0
# 1           0      1
# 2           0      1
# 3           0      1
# 4           0      1
# ...       ...    ...
# 83409       0      1
# 83410       0      1
# 83411       0      1
# 83412       0      1
# 83413       0      1
#
# [83414 rows x 2 columns]

# %% [markdown]
# # Get the latest trip for each unique ID
#
# In order to collapse the data properly, we need to use various aggregation methods, depending on the column. Here we list out each column explicitly and determine the best aggregation method for each.

# %%
# Convenience method for printing the dictionary contents
print(f'{len(df.columns)} columns:')
for col in df.columns:
    print(f"'{col}': methodhere,")
# Out:
# 28 columns:
# 'dt': methodhere,
# 'weekday': methodhere,
# 'id_driver': methodhere,
# 'id_carrier_number': methodhere,
# 'dim_carrier_type': methodhere,
# 'dim_carrier_company_name': methodhere,
# 'home_base_city': methodhere,
# 'home_base_state': methodhere,
# 'carrier_trucks': methodhere,
# 'num_trucks': methodhere,
# 'interested_in_drayage': methodhere,
# 'port_qualified': methodhere,
# 'signup_source': methodhere,
# 'ts_signup': methodhere,
# 'ts_first_approved': methodhere,
# 'days_signup_to_approval': methodhere,
# 'driver_with_twic': methodhere,
# 'dim_preferred_lanes': methodhere,
# 'first_load_date': methodhere,
# 'most_recent_load_date': methodhere,
# 'loads': methodhere,
# 'marketplace_loads_otr': methodhere,
# 'marketplace_loads_atlas': methodhere,
# 'marketplace_loads': methodhere,
# 'brokerage_loads_otr': methodhere,
# 'brokerage_loads_atlas': methodhere,
# 'brokerage_loads': methodhere,
# 'total_loads': methodhere,

# %%
# Aggregation methods
minimum = 'min'
maximum = 'max'
median = 'median'
random_mode = lambda x: random.choice(pd.Series.mode(x if isinstance(x, list) else list(x)))

aggregation = {
    'dt': maximum,
    'weekday': random_mode,
    'id_carrier_number': random_mode,
    'dim_carrier_type': random_mode,
    'dim_carrier_company_name': mode,
    'home_base_city': mode,
    'home_base_state': mode,
    'carrier_trucks': mode,
    'num_trucks': maximum,
    'interested_in_drayage': random_mode,
    'port_qualified': random_mode,
    'signup_source': random_mode,
    'ts_signup': maximum,
    'ts_first_approved': minimum,
    'days_signup_to_approval': maximum,
    'driver_with_twic': mode,
    'dim_preferred_lanes': mode,
    'first_load_date': minimum,
    'most_recent_load_date': maximum,
    'loads': random_mode,
    'marketplace_loads_otr': maximum,
    'marketplace_loads_atlas': maximum,
    'marketplace_loads': maximum,
    'brokerage_loads_otr': maximum,
    'brokerage_loads_atlas': maximum,
    'brokerage_loads': maximum,
    'total_loads': maximum
}

driver_most_recent = df.groupby(['id_driver']).agg(aggregation)

# %%
driver_most_recent
# Out:
#                   dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 20        2016-06-20        4          U0000035   Owner Operator
# 26        2015-10-29        4          U0000041   Owner Operator
# 27        2015-12-09        3          U0000042   Owner Operator
# 30        2018-12-05        3          U0000045   Owner Operator
# 31        2016-04-01        2          U0000046   Owner Operator
# ...              ...      ...               ...              ...
# 37977     2021-02-11        4          C0098303            Fleet
# 38039     2021-02-16        2          C0096844            Fleet
# 38060     2021-02-13        5          C0094651            Fleet
# 38065     2021-02-17        3          C0094651            Fleet
# 38096     2021-02-12        5          C0097727            Fleet
#
#                           dim_carrier_company_name home_base_city  \
# id_driver
# 20                                 Mega Fleet Corp       Pasadena
# 26                                             NaN  Sierra Madre,
# 27                                             NaN  Sierra Madre,
# 30                                 A & J Transport     Riverside
# 31                           lv transportation llc            NaN
# ...                                            ...            ...
# 37977      DOLPHIN TRANS, INC. DBA DOLPHIN EXPRESS        Norwalk
# 38039                        JT Transportation Inc    Los Angeles
# 38060                            NFS asset Drayage        Lynwood
# 38065                            NFS asset Drayage        Lynwood
# 38096                       New opportunities inc     Los Angeles
#
#           home_base_state             carrier_trucks  num_trucks  \
# id_driver
# 20                     CA                 ["dryvan"]         1.0
# 26                     CA                 ["dryvan"]         1.0
# 27                     CA                 ["dryvan"]         1.0
# 30                     CA                 ["reefer"]         1.0
# 31                    NaN                 ["dryvan"]         1.0
# ...                   ...                        ...         ...
# 37977                  CA              ["poweronly"]         1.0
# 38039                  CA                 ["dryvan"]         1.0
# 38060                  CA    ["poweronly", "dryvan"]       195.0
# 38065                  CA    ["poweronly", "dryvan"]       195.0
# 38096                  CA  ["poweronly", "boxtruck"]        15.0
#
#           interested_in_drayage  ... first_load_date most_recent_load_date  \
# id_driver                        ...
# 20                not specified  ...      2015-10-23            2016-06-20
# 26                not specified  ...      2015-10-29            2015-10-29
# 27                not specified  ...      2015-10-18            2015-12-09
# 30                not specified  ...      2018-10-30            2018-12-05
# 31                not specified  ...      2016-02-28            2016-04-01
# ...                         ...  ...             ...                   ...
# 37977                       yes  ...      2021-02-11            2021-02-11
# 38039             not specified  ...      2021-02-16            2021-02-16
# 38060                       yes  ...      2021-02-12            2021-02-13
# 38065                       yes  ...      2021-02-15            2021-02-17
# 38096                       yes  ...      2021-02-12            2021-02-12
#
#           loads marketplace_loads_otr  marketplace_loads_atlas  \
# id_driver
# 20            1                     0                        0
# 26            1                     0                        0
# 27            1                     0                        0
# 30            1                     0                        0
# 31            1                     0                        0
# ...         ...                   ...                      ...
# 37977         2                     0                        0
# 38039         1                     1                        0
# 38060         2                     0                        0
# 38065         2                     0                        0
# 38096         1                     0                        1
#
#           marketplace_loads brokerage_loads_otr brokerage_loads_atlas  \
# id_driver
# 20                        0                  42                     0
# 26                        0                   1                     0
# 27                        0                  11                     0
# 30                        0                   4                     0
# 31                        0                  15                     0
# ...                     ...                 ...                   ...
# 37977                     0                   0                     2
# 38039                     1                   0                     0
# 38060                     0                   0                     0
# 38065                     0                   0                     0
# 38096                     1                   0                     0
#
#           brokerage_loads  total_loads
# id_driver
# 20                     42           42
# 26                      1            1
# 27                     11           11
# 30                      4            4
# 31                     15           15
# ...                   ...          ...
# 37977                   2            2
# 38039                   0            1
# 38060                   0            3
# 38065                   0            7
# 38096                   0            1
#
# [5288 rows x 27 columns]

# %%
approved = driver_most_recent[driver_most_recent.days_signup_to_approval.isnull() == False]

# %%
approved.days_signup_to_approval
# Out:
# id_driver
# 30       1136.0
# 41       1141.0
# 50       1193.0
# 64       1275.0
# 184      1261.0
#           ...
# 37977      35.0
# 38039      20.0
# 38060       0.0
# 38065       0.0
# 38096      18.0
# Name: days_signup_to_approval, Length: 3963, dtype: float64

# %% [markdown]
# ## Add boolean column for "self owned" or not

# %%
driver_most_recent['self_owned'] = False
driver_most_recent['self_owned'] = label_encoder.fit_transform(driver_most_recent.index.isin(self_owned))

# %%
driver_most_recent
# Out:
#                    dt  weekday id_carrier_number  \
# id_driver
# 20         2016-06-20        7          U0000035
# 26         2015-10-29        4          U0000041
# 27         2015-12-09        7          U0000042
# 30         2018-12-05        3          U0000045
# 31         2016-04-01        7          U0000046
# ...               ...      ...               ...
# 37977      2021-02-11        4          C0098303
# 38039      2021-02-16        2          C0096844
# 38060      2021-02-13        6          C0094651
# 38065      2021-02-17        3          C0094651
# 38096      2021-02-12        5          C0097727
#
#                           dim_carrier_company_name home_base_city  \
# id_driver
# 20                                 Mega Fleet Corp       Pasadena
# 26                                             NaN  Sierra Madre,
# 27                                             NaN  Sierra Madre,
# 30                                 A & J Transport     Riverside
# 31                           lv transportation llc            NaN
# ...                                            ...            ...
# 37977      DOLPHIN TRANS, INC. DBA DOLPHIN EXPRESS        Norwalk
# 38039                        JT Transportation Inc    Los Angeles
# 38060                            NFS asset Drayage        Lynwood
# 38065                            NFS asset Drayage        Lynwood
# 38096                       New opportunities inc     Los Angeles
#
#           home_base_state             carrier_trucks  num_trucks  \
# id_driver
# 20                     CA                 ["dryvan"]         1.0
# 26                     CA                 ["dryvan"]         1.0
# 27                     CA                 ["dryvan"]         1.0
# 30                     CA                 ["reefer"]         1.0
# 31                    NaN                 ["dryvan"]         1.0
# ...                   ...                        ...         ...
# 37977                  CA              ["poweronly"]         1.0
# 38039                  CA                 ["dryvan"]         1.0
# 38060                  CA    ["poweronly", "dryvan"]       195.0
# 38065                  CA    ["poweronly", "dryvan"]       195.0
# 38096                  CA  ["poweronly", "boxtruck"]        15.0
#
#           interested_in_drayage port_qualified  ...    load_day loads  \
# id_driver                                       ...
# 20                not specified             no  ...  2016-06-20     4
# 26                not specified             no  ...  2015-10-29     1
# 27                not specified             no  ...  2015-12-09     2
# 30                not specified             no  ...  2018-12-05     1
# 31                not specified             no  ...  2016-04-01     4
# ...                         ...            ...  ...         ...   ...
# 37977                       yes            yes  ...  2021-02-11     2
# 38039             not specified             no  ...  2021-02-16     1
# 38060                       yes            yes  ...  2021-02-13     2
# 38065                       yes            yes  ...  2021-02-17     3
# 38096                       yes            yes  ...  2021-02-12     1
#
#           marketplace_loads_otr  marketplace_loads_atlas marketplace_loads  \
# id_driver
# 20                            0                        0                 0
# 26                            0                        0                 0
# 27                            0                        0                 0
# 30                            0                        0                 0
# 31                            0                        0                 0
# ...                         ...                      ...               ...
# 37977                         0                        0                 0
# 38039                         1                        0                 1
# 38060                         0                        0                 0
# 38065                         0                        0                 0
# 38096                         0                        1                 1
#
#           brokerage_loads_otr brokerage_loads_atlas brokerage_loads  \
# id_driver
# 20                         42                     0              42
# 26                          1                     0               1
# 27                         11                     0              11
# 30                          4                     0               4
# 31                         15                     0              15
# ...                       ...                   ...             ...
# 37977                       0                     2               2
# 38039                       0                     0               0
# 38060                       0                     0               0
# 38065                       0                     0               0
# 38096                       0                     0               0
#
#           total_loads  self_owned
# id_driver
# 20                 42           1
# 26                  1           1
# 27                 11           1
# 30                  4           1
# 31                 15           1
# ...               ...         ...
# 37977               2           0
# 38039               1           0
# 38060               3           0
# 38065               7           0
# 38096               1           0
#
# [5288 rows x 28 columns]

# %% [markdown]
# ## Add columns for mean, median, and standard deviation of dates

# %%
df['Date_int'] = pd.to_datetime(df['dt']).astype(int)
res = df.groupby('id_driver').agg(['mean', 'median', 'std'])
res.columns = ['_'.join(c) for c in res.columns.values]

res['Date_mean'] = pd.to_datetime(res['Date_int_mean'])
res['Date_median'] = pd.to_datetime(res['Date_int_median'])
res['Date_std'] = pd.to_timedelta(res['Date_int_std'])
res = res[['Date_mean', 'Date_median', 'Date_std']]

driver_most_recent['dt_mean'] = res['Date_mean']
driver_most_recent['dt_median'] = res['Date_median']
driver_most_recent['dt_std'] = res['Date_std']
# driver_most_recent.drop(columns=['Date_int'], inplace=True)

# %%
driver_most_recent.head()
# Out:
#                    dt  weekday id_carrier_number dim_carrier_company_name  \
# id_driver
# 20         2016-06-20        7          U0000035          Mega Fleet Corp
# 26         2015-10-29        4          U0000041                      NaN
# 27         2015-12-09        7          U0000042                      NaN
# 30         2018-12-05        3          U0000045          A & J Transport
# 31         2016-04-01        7          U0000046    lv transportation llc
#
#           home_base_city home_base_state carrier_trucks  num_trucks  \
# id_driver
# 20              Pasadena              CA     ["dryvan"]         1.0
# 26         Sierra Madre,              CA     ["dryvan"]         1.0
# 27         Sierra Madre,              CA     ["dryvan"]         1.0
# 30            Riverside               CA     ["reefer"]         1.0
# 31                   NaN             NaN     ["dryvan"]         1.0
#
#           interested_in_drayage port_qualified  ... marketplace_loads_atlas  \
# id_driver                                       ...
# 20                not specified             no  ...                       0
# 26                not specified             no  ...                       0
# 27                not specified             no  ...                       0
# 30                not specified             no  ...                       0
# 31                not specified             no  ...                       0
#
#           marketplace_loads brokerage_loads_otr  brokerage_loads_atlas  \
# id_driver
# 20                        0                  42                      0
# 26                        0                   1                      0
# 27                        0                  11                      0
# 30                        0                   4                      0
# 31                        0                  15                      0
#
#           brokerage_loads total_loads self_owned  \
# id_driver
# 20                     42          42          1
# 26                      1           1          1
# 27                     11          11          1
# 30                      4           4          1
# 31                     15          15          1
#
#                                 dt_mean           dt_median  \
# id_driver
# 20        2016-01-13 09:46:40.000000000 2015-12-29 00:00:00
# 26        2015-10-29 00:00:00.000000000 2015-10-29 00:00:00
# 27        2015-11-15 16:00:00.000000000 2015-11-23 00:00:00
# 30        2018-11-16 18:00:00.000000000 2018-11-16 12:00:00
# 31        2016-03-17 10:54:32.727272704 2016-03-15 00:00:00
#
#                               dt_std
# id_driver
# 20        60 days 03:42:24.874807908
# 26                               NaT
# 27        18 days 16:21:25.202212076
# 30        19 days 22:32:52.091717299
# 31        12 days 00:16:21.353745482
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Add columns for mean, median, and standard deviation of weekday

# %%
driver_most_recent['weekday_mean'] = round(df.groupby('id_driver').weekday.agg(['mean'])).astype(int)
driver_most_recent['weekday_median'] = round(df.groupby('id_driver').weekday.agg(['median'])).astype(int)
driver_most_recent['weekday_std'] = round(df.groupby('id_driver').weekday.agg(['std']))
driver_most_recent.drop(columns=['weekday'], inplace=True)

# %%
driver_most_recent
# Out:
#                    dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 20         2016-06-20        7          U0000035   Owner Operator
# 26         2015-10-29        4          U0000041   Owner Operator
# 27         2015-12-09        7          U0000042   Owner Operator
# 30         2018-12-05        3          U0000045   Owner Operator
# 31         2016-04-01        7          U0000046   Owner Operator
# ...               ...      ...               ...              ...
# 37977      2021-02-11        4          C0098303            Fleet
# 38039      2021-02-16        2          C0096844            Fleet
# 38060      2021-02-13        6          C0094651            Fleet
# 38065      2021-02-17        3          C0094651            Fleet
# 38096      2021-02-12        5          C0097727            Fleet
#
#                           dim_carrier_company_name home_base_city  \
# id_driver
# 20                                 Mega Fleet Corp       Pasadena
# 26                                             NaN  Sierra Madre,
# 27                                             NaN  Sierra Madre,
# 30                                 A & J Transport     Riverside
# 31                           lv transportation llc            NaN
# ...                                            ...            ...
# 37977      DOLPHIN TRANS, INC. DBA DOLPHIN EXPRESS        Norwalk
# 38039                        JT Transportation Inc    Los Angeles
# 38060                            NFS asset Drayage        Lynwood
# 38065                            NFS asset Drayage        Lynwood
# 38096                       New opportunities inc     Los Angeles
#
#           home_base_state             carrier_trucks  num_trucks  \
# id_driver
# 20                     CA                 ["dryvan"]         1.0
# 26                     CA                 ["dryvan"]         1.0
# 27                     CA                 ["dryvan"]         1.0
# 30                     CA                 ["reefer"]         1.0
# 31                    NaN                 ["dryvan"]         1.0
# ...                   ...                        ...         ...
# 37977                  CA              ["poweronly"]         1.0
# 38039                  CA                 ["dryvan"]         1.0
# 38060                  CA    ["poweronly", "dryvan"]       195.0
# 38065                  CA    ["poweronly", "dryvan"]       195.0
# 38096                  CA  ["poweronly", "boxtruck"]        15.0
#
#           interested_in_drayage  ... dim_preferred_lanes first_load_date  \
# id_driver                        ...
# 20                not specified  ...                 NaN      2015-10-23
# 26                not specified  ...                 NaN      2015-10-29
# 27                not specified  ...                 NaN      2015-10-18
# 30                not specified  ...                 NaN      2018-10-30
# 31                not specified  ...                 NaN      2016-02-28
# ...                         ...  ...                 ...             ...
# 37977                       yes  ...                 NaN      2021-02-11
# 38039             not specified  ...                 NaN      2021-02-16
# 38060                       yes  ...                 NaN      2021-02-12
# 38065                       yes  ...                 NaN      2021-02-15
# 38096                       yes  ...                 NaN      2021-02-12
#
#           loads marketplace_loads_otr  marketplace_loads_atlas  \
# id_driver
# 20            4                     0                        0
# 26            1                     0                        0
# 27            2                     0                        0
# 30            1                     0                        0
# 31            4                     0                        0
# ...         ...                   ...                      ...
# 37977         2                     0                        0
# 38039         1                     1                        0
# 38060         2                     0                        0
# 38065         3                     0                        0
# 38096         1                     0                        1
#
#           marketplace_loads brokerage_loads_otr brokerage_loads_atlas  \
# id_driver
# 20                        0                  42                     0
# 26                        0                   1                     0
# 27                        0                  11                     0
# 30                        0                   4                     0
# 31                        0                  15                     0
# ...                     ...                 ...                   ...
# 37977                     0                   0                     2
# 38039                     1                   0                     0
# 38060                     0                   0                     0
# 38065                     0                   0                     0
# 38096                     1                   0                     0
#
#            brokerage_loads  total_loads
# id_driver
# 20                      42           42
# 26                       1            1
# 27                      11           11
# 30                       4            4
# 31                      15           15
# ...                    ...          ...
# 37977                    2            2
# 38039                    0            1
# 38060                    0            3
# 38065                    0            7
# 38096                    0            1
#
# [5288 rows x 26 columns]

# %%
driver_most_recent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5288 entries, 20 to 38096
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   dt                        5288 non-null   object
#  1   id_carrier_number         5288 non-null   object
#  2   dim_carrier_company_name  5281 non-null   object
#  3   home_base_city            5276 non-null   object
#  4   home_base_state           5276 non-null   object
#  5   carrier_trucks            5288 non-null   object
#  6   num_trucks                5246 non-null   float64
#  7   interested_in_drayage     5288 non-null   object
#  8   port_qualified            5288 non-null   object
#  9   signup_source             5288 non-null   object
#  10  ts_signup                 5288 non-null   object
#  11  ts_first_approved         3963 non-null   object
#  12  days_signup_to_approval   3963 non-null   float64
#  13  driver_with_twic          5288 non-null   object
#  14  dim_preferred_lanes       193 non-null    object
#  15  first_load_date           5288 non-null   object
#  16  most_recent_load_date     5288 non-null   object
#  17  load_day                  5288 non-null   object
#  18  loads                     5288 non-null   int64
#  19  marketplace_loads_otr     5288 non-null   int64
#  20  marketplace_loads_atlas   5288 non-null   int64
#  21  marketplace_loads         5288 non-null   int64
#  22  brokerage_loads_otr       5288 non-null   int64
#  23  brokerage_loads_atlas     5288 non-null   int64
#  24  brokerage_loads           5288 non-null   int64
#  25  total_loads               5288 non-null   int64
#  26  self_owned                5288 non-null   int64
#  27  dt_mean                   5288 non-null   datetime64[ns]
#  28  dt_median                 5288 non-null   datetime64[ns]
#  29  dt_std                    3553 non-null   timedelta64[ns]
#  30  weekday_mean              5288 non-null   int64
#  31  weekday_median            5288 non-null   int64
#  32  weekday_std               3553 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(11), object(16), timedelta64[ns](1)
# memory usage: 1.5+ MB

# %% [markdown]
# # Part 1 - Generate Labels
#
# Where drivers in the 75th percentile of `total_loads` and the 75th percentile of `most_recent_load_date` are assigned a label of 1 (indicating a high performing driver) with all others being assigned a 0 - (NOTE: your labels will likely be unbalanced. You will need to determine an approach to balancing your labels).

# %% [markdown]
# ## Total Loads
#
# ### Option 1 - `total_loads` from the entire dataset

# %%
plt.figure(figsize=(12,4))
df.total_loads.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
top_loads = df.total_loads.quantile(0.75)
print(f'The top 75th percentile of loads is >= {top_loads}')
# Out:
# The top 75th percentile of loads is >= 325.0

# %% [markdown]
# ### Option 2 - `total_loads` from the collapsed dataset

# %%
plt.figure(figsize=(12,4))
driver_most_recent.total_loads.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
top_loads = driver_most_recent.total_loads.quantile(0.75)
print(f'The top 75th percentile of loads is >= {top_loads}')
# Out:
# The top 75th percentile of loads is >= 17.0

# %% [markdown]
# ## Most Recent Load Date
#
# ### Option 1 - `most_recent_load_date` from the full dataset

# %%
plt.figure(figsize=(12,4))
df.most_recent_load_date.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
top_most_recent = df.most_recent_load_date.quantile(0.75)
print(f'The top 75th percentile of most_recent_load_date falls on {top_most_recent}')
# Out:
# The top 75th percentile of most_recent_load_date falls on 2021-02-14 00:00:00

# %% [markdown]
# ### Option 2 - `most_recent_load_date` from the collapsed dataset

# %%
plt.figure(figsize=(12,4))
driver_most_recent.most_recent_load_date.hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
top_most_recent = driver_most_recent.most_recent_load_date.quantile(0.75)
print(f'The top 75th percentile of most_recent_load_date falls on {top_most_recent}')
# Out:
# The top 75th percentile of most_recent_load_date falls on 2020-05-19 00:00:00

# %% [markdown]
# ## Combinations of the above options
#
# ### Option 1&1 (requires collapsing again)

# %%
top_loads = df.total_loads.quantile(0.75)
top_most_recent = df.most_recent_load_date.quantile(0.75)
top = df[(df.total_loads >= top_loads) & (df.most_recent_load_date >= top_most_recent)]
top = top.groupby('id_driver').agg('max')
top
# Out:
#                   dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 3851      2021-02-17        7          U0093691   Owner Operator
# 4516      2021-02-16        7          C0090399            Fleet
# 4524      2021-02-15        7          C0090405            Fleet
# 7879      2021-02-14        7          C0090913            Fleet
# 13215     2021-02-16        7          U0101600   Owner Operator
# 14657     2021-02-16        7          C0093129            Fleet
# 15913     2021-02-16        7          C0091573            Fleet
# 16075     2021-02-15        7          C0093546            Fleet
# 16280     2021-02-14        7          U0104254   Owner Operator
# 16299     2021-02-16        7          U0104273   Owner Operator
# 17388     2021-02-16        7          C0093895            Fleet
# 18146     2021-02-17        7          U0105836   Owner Operator
# 18583     2021-02-17        5          U0106276   Owner Operator
# 18868     2021-02-17        7          U0106558   Owner Operator
# 19708     2021-02-16        7          U0107444   Owner Operator
# 20443     2021-02-17        7          C0093895            Fleet
# 21350     2021-02-17        7          U0109015   Owner Operator
# 21553     2021-02-16        7          U0109225   Owner Operator
# 21710     2021-02-17        7          U0109384   Owner Operator
# 22194     2021-02-16        7          U0109844   Owner Operator
# 22478     2021-02-17        7          U0110113   Owner Operator
# 24817     2021-02-17        7          U0112338   Owner Operator
# 26536     2021-02-17        7          U0114020   Owner Operator
# 26609     2021-02-16        7          C0095984            Fleet
# 26690     2021-02-15        7          U0114256   Owner Operator
# 26723     2021-02-17        7          C0094987            Fleet
# 27358     2021-02-17        6          U0114925   Owner Operator
# 28224     2021-02-17        7          U0115809   Owner Operator
# 28285     2021-02-16        7          C0096446            Fleet
# 28698     2021-02-16        7          U0116287   Owner Operator
# 31146     2021-02-16        7          U0118443   Owner Operator
# 31690     2021-02-17        6          U0118858   Owner Operator
# 32076     2021-02-17        7          U0119174   Owner Operator
# 32317     2021-02-16        7          U0119394   Owner Operator
# 32379     2021-02-16        7          U0119458   Owner Operator
# 33054     2021-02-15        6          C0095478            Fleet
# 33064     2021-02-17        7          U0120091   Owner Operator
# 33499     2021-02-17        6          C0097561            Fleet
# 34398     2021-02-17        7          U0121239   Owner Operator
# 34784     2021-02-17        7          C0097561            Fleet
# 34827     2021-02-16        7          C0097856            Fleet
# 34829     2021-02-17        7          C0097856            Fleet
# 34946     2021-02-16        6          U0121572   Owner Operator
# 35150     2021-02-17        7          C0097242            Fleet
# 35544     2021-02-15        7          C0097242            Fleet
# 35581     2021-02-17        6          U0122053   Owner Operator
# 35605     2021-02-16        5          C0098064            Fleet
# 36268     2021-02-16        6          C0098247            Fleet
# 36275     2021-02-17        7          U0122637   Owner Operator
# 36489     2021-02-17        7          U0122823   Owner Operator
# 36637     2021-02-17        7          C0098403            Fleet
# 36659     2021-02-17        7          U0122971   Owner Operator
# 36717     2021-02-17        7          C0095984            Fleet
# 36873     2021-02-16        7          U0123167   Owner Operator
# 37084     2021-02-17        7          C0098562            Fleet
#
#                        dim_carrier_company_name    home_base_city  \
# id_driver
# 3851                           pappy's trucking       Los Angeles
# 4516                                ABF FREIGHT        Fort Smith
# 4524                         Daylight Transport        Long Beach
# 7879                   the custom companies inc         Northlake
# 13215          West East Men Transportation Inc        Long Beach
# 14657                                USA Global         La Mirada
# 15913             Global Express Trucking Corp.         San Diego
# 16075                         SARINANA TRUCKING         Santa Ana
# 16280                   JC&A Transportation Inc       Los Angeles
# 16299                            BRJS TRANSPORT         Paramount
# 17388                              EJG TRUCKING       Los Angeles
# 18146             Prime Transportation Services     Moreno Valley
# 18583                 Miguel Casillas Transport         San Dimas
# 18868                          EBF trucking inc            Carson
# 19708                    CHUMATO TRANSPORTATION        Montebello
# 20443                              EJG TRUCKING       Los Angeles
# 21350                             CA&F TRUCKING           Maywood
# 21553                    Navarrete Trucking Inc       Los Angeles
# 21710                        TAQWA TRUCKING LLC         Inglewood
# 22194                  LA Trucker Transport LLC           Compton
# 22478                       Nelsons Deliveries        Los Angeles
# 24817                         Caveman transport           Fontana
# 26536                        Clovis express inc           Fontana
# 26609        WESTERN CONTAIN TRANSPORTATION LLC       Los Angeles
# 26690                         Luis alberto penA       Los Angeles
# 26723                     Pronto Logistics Corp          Alhambra
# 27358      MARK A VILLANUEVA DBA GRUNT TRUCKING            Carson
# 28224                       Juan Ramon Gonzalez       Victorville
# 28285                   ROADMOND LOGISTICS INC.         San Diego
# 28698                       Sansur trucking inc         Irwindale
# 31146                         CHS Trucking inc.        Long Beach
# 31690              FERNANDEZ TRANSPORTATION INC        South Gate
# 32076                           Bunny transport           Lynwood
# 32317                        KGLX TRANSPORT LLC       Yorba Linda
# 32379                       Aleman trucking llc        Long Beach
# 33054                         757 TRANSPORT INC           Lynwood
# 33064                       Taak'in Transporter           Norwalk
# 33499                         ADC TRANSPORT INC         Paramount
# 34398                   Morales transportation             Downey
# 34784                         ADC TRANSPORT INC         Paramount
# 34827                          PEREIRA BROS LLC          Torrance
# 34829                          PEREIRA BROS LLC          Torrance
# 34946                    CHEO'S TRUCKING, INC.             Perris
# 35150                              MRH TRUCKING       Los Angeles
# 35544                              MRH TRUCKING       Los Angeles
# 35581                  Eagle star logistics inc     Moreno Valley
# 35605                       M RIOS TRUCKING INC         San Diego
# 36268                          SAMY´S TRANSPORT         San Diego
# 36275                          JJK Trucking Inc          Rosemead
# 36489                     SHUANG YANG TRUCK INC            Santee
# 36637                                      SDLM        Long Beach
# 36659                     KINGKONG TRUCKING INC  Hacienda Heights
# 36717        WESTERN CONTAIN TRANSPORTATION LLC       Los Angeles
# 36873                   ETL Transportation Inc.     Mission Viejo
# 37084                States Runner Trucking Inc            Downey
#
#           home_base_state           carrier_trucks  num_trucks  \
# id_driver
# 3851                   CA               ["dryvan"]         1.0
# 4516                   AR               ["dryvan"]         2.0
# 4524                   CA               ["dryvan"]         6.0
# 7879                   IL               ["dryvan"]         2.0
# 13215                  CA            ["poweronly"]         1.0
# 14657                  CA               ["dryvan"]         1.0
# 15913                  CA  ["dryvan", "poweronly"]         5.0
# 16075                  CA            ["poweronly"]         1.0
# 16280                  CA            ["poweronly"]         1.0
# 16299                  CA            ["poweronly"]         1.0
# 17388                  CA   ["dryvan", "boxtruck"]        11.0
# 18146                  CA            ["poweronly"]         1.0
# 18583                  CA            ["poweronly"]         1.0
# 18868                  CA            ["poweronly"]         1.0
# 19708                  CA            ["poweronly"]         1.0
# 20443                  CA   ["dryvan", "boxtruck"]        11.0
# 21350                  CA            ["poweronly"]         1.0
# 21553                  CA            ["poweronly"]         1.0
# 21710                  CA            ["poweronly"]         1.0
# 22194                  CA            ["poweronly"]         1.0
# 22478                  CA             ["boxtruck"]         1.0
# 24817                  CA            ["poweronly"]         1.0
# 26536                  CA               ["dryvan"]         1.0
# 26609                  CA            ["poweronly"]         4.0
# 26690                  CA            ["poweronly"]         1.0
# 26723                  CA               ["dryvan"]         1.0
# 27358                  CA            ["poweronly"]         1.0
# 28224                  CA            ["poweronly"]         1.0
# 28285                  CA  ["dryvan", "poweronly"]        31.0
# 28698                  CA            ["poweronly"]         1.0
# 31146                  CA            ["poweronly"]         1.0
# 31690                  CA            ["poweronly"]         1.0
# 32076                  CA            ["poweronly"]         1.0
# 32317                  CA            ["poweronly"]         1.0
# 32379                  CA            ["poweronly"]         1.0
# 33054                  CA            ["poweronly"]        10.0
# 33064                  CA            ["poweronly"]         1.0
# 33499                  CA            ["poweronly"]         9.0
# 34398                  CA            ["poweronly"]         1.0
# 34784                  CA            ["poweronly"]         9.0
# 34827                  CA            ["poweronly"]         3.0
# 34829                  CA            ["poweronly"]         3.0
# 34946                  CA            ["poweronly"]         1.0
# 35150                  CA            ["poweronly"]         2.0
# 35544                  CA            ["poweronly"]         2.0
# 35581                  CA            ["poweronly"]         1.0
# 35605                  CA               ["dryvan"]         1.0
# 36268                  CA               ["dryvan"]         1.0
# 36275                  CA            ["poweronly"]         1.0
# 36489                  CA            ["poweronly"]         1.0
# 36637                  CA            ["poweronly"]         2.0
# 36659                  CA            ["poweronly"]         1.0
# 36717                  CA            ["poweronly"]         4.0
# 36873                  CA            ["poweronly"]         1.0
# 37084                  CA            ["poweronly"]         2.0
#
#           interested_in_drayage  ... first_load_date most_recent_load_date  \
# id_driver                        ...
# 3851              not specified  ...      2017-06-27            2021-02-17
# 4516              not specified  ...      2018-07-31            2021-02-16
# 4524              not specified  ...      2017-01-20            2021-02-15
# 7879                        yes  ...      2016-06-02            2021-02-14
# 13215                       yes  ...      2020-01-27            2021-02-16
# 14657                       yes  ...      2018-10-02            2021-02-16
# 15913             not specified  ...      2018-11-07            2021-02-16
# 16075             not specified  ...      2018-11-15            2021-02-15
# 16280                       yes  ...      2020-08-31            2021-02-14
# 16299                       yes  ...      2020-01-06            2021-02-16
# 17388                       yes  ...      2018-12-22            2021-02-16
# 18146                       yes  ...      2019-01-19            2021-02-17
# 18583                       yes  ...      2019-01-28            2021-02-17
# 18868             not specified  ...      2019-02-08            2021-02-17
# 19708             not specified  ...      2019-02-22            2021-02-16
# 20443                       yes  ...      2019-03-14            2021-02-17
# 21350                       yes  ...      2019-10-24            2021-02-17
# 21553             not specified  ...      2019-04-26            2021-02-16
# 21710                       yes  ...      2019-11-13            2021-02-17
# 22194             not specified  ...      2019-05-01            2021-02-17
# 22478             not specified  ...      2019-05-22            2021-02-17
# 24817                       yes  ...      2019-08-08            2021-02-17
# 26536                       yes  ...      2019-08-16            2021-02-17
# 26609                       yes  ...      2019-08-03            2021-02-16
# 26690                       yes  ...      2020-07-15            2021-02-15
# 26723             not specified  ...      2019-08-07            2021-02-17
# 27358                       yes  ...      2020-07-01            2021-02-17
# 28224                       yes  ...      2019-09-16            2021-02-17
# 28285                       yes  ...      2019-09-18            2021-02-16
# 28698                       yes  ...      2019-10-03            2021-02-16
# 31146                       yes  ...      2019-12-30            2021-02-16
# 31690                       yes  ...      2020-08-10            2021-02-17
# 32076                       yes  ...      2020-02-06            2021-02-17
# 32317                       yes  ...      2020-02-06            2021-02-16
# 32379                       yes  ...      2020-10-29            2021-02-16
# 33054                       yes  ...      2020-02-12            2021-02-15
# 33064                       yes  ...      2020-02-11            2021-02-17
# 33499                       yes  ...      2020-03-03            2021-02-17
# 34398                       yes  ...      2020-05-22            2021-02-17
# 34784                       yes  ...      2020-06-15            2021-02-17
# 34827                       yes  ...      2020-06-18            2021-02-16
# 34829                       yes  ...      2020-06-13            2021-02-17
# 34946                       yes  ...      2020-07-02            2021-02-16
# 35150                       yes  ...      2020-06-26            2021-02-17
# 35544                       yes  ...      2020-08-06            2021-02-15
# 35581                       yes  ...      2020-10-16            2021-02-17
# 35605                       yes  ...      2020-08-11            2021-02-16
# 36268                       yes  ...      2020-10-03            2021-02-16
# 36275                       yes  ...      2020-10-04            2021-02-17
# 36489                       yes  ...      2020-10-20            2021-02-17
# 36637                       yes  ...      2020-10-31            2021-02-17
# 36659                       yes  ...      2020-11-03            2021-02-17
# 36717                       yes  ...      2020-11-05            2021-02-17
# 36873                       yes  ...      2020-11-21            2021-02-16
# 37084                       yes  ...      2020-12-04            2021-02-17
#
#           loads marketplace_loads_otr  marketplace_loads_atlas  \
# id_driver
# 3851          4                   286                        4
# 4516         28                     0                        0
# 4524         22                     0                        0
# 7879          7                     0                        0
# 13215         9                     0                      423
# 14657        16                     1                        0
# 15913         4                     2                        0
# 16075        22                     0                        0
# 16280        14                     0                      417
# 16299         8                     5                     1068
# 17388        31                   195                        0
# 18146        15                    48                     1289
# 18583         9                     6                      387
# 18868         4                   476                        0
# 19708        10                   301                       60
# 20443        14                   205                        0
# 21350         7                     0                      438
# 21553        10                   108                        6
# 21710         7                     0                      387
# 22194        15                   257                      826
# 22478        12                     2                        0
# 24817        11                    84                       54
# 26536        13                     3                      940
# 26609        12                     2                      895
# 26690         7                     0                      394
# 26723        10                    24                      365
# 27358        11                     0                      150
# 28224        14                     0                      441
# 28285       102                     0                        0
# 28698        13                    24                     1324
# 31146        10                     3                      325
# 31690         8                     0                      429
# 32076         7                     0                      581
# 32317         8                     0                      743
# 32379        10                     0                      350
# 33054         8                     2                      505
# 33064         9                     0                      355
# 33499        13                    28                      278
# 34398         9                     0                      263
# 34784         8                    11                      429
# 34827         9                     0                      291
# 34829        14                     0                      991
# 34946        10                     0                      378
# 35150         7                     0                      364
# 35544         8                     0                      317
# 35581         9                     0                      369
# 35605        50                     0                        0
# 36268        26                     0                        0
# 36275        11                     0                      387
# 36489        11                     0                      473
# 36637        11                     0                      331
# 36659        10                     0                       92
# 36717         9                     0                      307
# 36873        11                     0                      329
# 37084        10                     0                      311
#
#           marketplace_loads  brokerage_loads_otr brokerage_loads_atlas  \
# id_driver
# 3851                    290                  226                     0
# 4516                      0                 1255                     0
# 4524                      0                 2671                     0
# 7879                      0                  346                     0
# 13215                   423                    0                    11
# 14657                     1                  517                     0
# 15913                     2                  419                     0
# 16075                     0                  669                     0
# 16280                   417                    0                   247
# 16299                  1073                    0                    35
# 17388                   195                  233                     0
# 18146                  1337                    3                    34
# 18583                   393                    2                    61
# 18868                   476                   33                     0
# 19708                   361                  236                     3
# 20443                   205                  307                     0
# 21350                   438                    0                    45
# 21553                   114                  331                     2
# 21710                   387                    0                    88
# 22194                  1083                  148                    34
# 22478                     2                  845                     0
# 24817                   138                  260                     3
# 26536                   943                    0                    16
# 26609                   897                    0                    93
# 26690                   394                    0                    46
# 26723                   389                   23                   120
# 27358                   150                    0                   175
# 28224                   441                    0                    74
# 28285                     0                 4266                     0
# 28698                  1348                    0                    39
# 31146                   328                    0                    27
# 31690                   429                    0                   145
# 32076                   581                    0                     5
# 32317                   743                    0                    77
# 32379                   350                    0                    36
# 33054                   507                    3                    57
# 33064                   355                    0                    15
# 33499                   306                    0                   323
# 34398                   263                    0                   100
# 34784                   440                    0                   167
# 34827                   291                    0                    52
# 34829                   991                    0                   202
# 34946                   378                    0                   204
# 35150                   364                    0                    27
# 35544                   317                    0                    34
# 35581                   369                    0                    44
# 35605                     0                  443                     0
# 36268                     0                  348                     0
# 36275                   387                    0                   145
# 36489                   473                    0                   100
# 36637                   331                    0                    12
# 36659                    92                    0                   296
# 36717                   307                    0                    21
# 36873                   329                    0                    20
# 37084                   311                    0                    17
#
#           brokerage_loads  total_loads
# id_driver
# 3851                  226          516
# 4516                 1255         1255
# 4524                 2671         2671
# 7879                  346          346
# 13215                  11          434
# 14657                 517          518
# 15913                 419          421
# 16075                 669          669
# 16280                 247          664
# 16299                  35         1108
# 17388                 233          428
# 18146                  37         1374
# 18583                  63          456
# 18868                  33          509
# 19708                 239          600
# 20443                 307          512
# 21350                  45          483
# 21553                 333          447
# 21710                  88          475
# 22194                 182         1265
# 22478                 845          847
# 24817                 263          401
# 26536                  16          959
# 26609                  93          990
# 26690                  46          440
# 26723                 143          532
# 27358                 175          325
# 28224                  74          515
# 28285                4266         4266
# 28698                  39         1387
# 31146                  27          355
# 31690                 145          574
# 32076                   5          586
# 32317                  77          820
# 32379                  36          386
# 33054                  60          567
# 33064                  15          370
# 33499                 323          629
# 34398                 100          363
# 34784                 167          607
# 34827                  52          343
# 34829                 202         1193
# 34946                 204          582
# 35150                  27          391
# 35544                  34          351
# 35581                  44          413
# 35605                 443          443
# 36268                 348          348
# 36275                 145          532
# 36489                 100          573
# 36637                  12          343
# 36659                 296          388
# 36717                  21          328
# 36873                  20          349
# 37084                  17          328
#
# [55 rows x 27 columns]

# %% [markdown]
# ### Option 1&2 (requires collapsing again)

# %%
top_loads = df.total_loads.quantile(0.75)
top_most_recent = driver_most_recent.most_recent_load_date.quantile(0.75)
top = df[(df.total_loads >= top_loads) & (driver_most_recent.most_recent_load_date >= top_most_recent)]
top = top.groupby('id_driver').agg('max')
top
# Out:
#                   dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 33        2017-11-03        5          U0000048   Owner Operator
# 38        2017-07-17        4          U0000054   Owner Operator
# 41        2019-08-23        5          U0000058   Owner Operator
# 154       2017-10-08        7          U0090195   Owner Operator
# 329       2017-03-17        6          C0090004            Fleet
# ...              ...      ...               ...              ...
# 35581     2021-02-12        5          U0122053   Owner Operator
# 36275     2021-01-23        6          U0122637   Owner Operator
# 36637     2020-11-13        5          C0098403            Fleet
# 36717     2021-02-06        6          C0095984            Fleet
# 37231     2020-12-28        1          C0098259            Fleet
#
#                      dim_carrier_company_name    home_base_city  \
# id_driver
# 33                              iDC Logistics      Sierra Madre
# 38                              iDC Logistics     Sierra Madre,
# 41                  SHALISA & VP TRUCKING LLC         Hawthorne
# 154                                       IDC     Sierra Madre,
# 329                                   IDC OTR  City of industry
# ...                                       ...               ...
# 35581                Eagle star logistics inc     Moreno Valley
# 36275                        JJK Trucking Inc          Rosemead
# 36637                                    SDLM        Long Beach
# 36717      WESTERN CONTAIN TRANSPORTATION LLC       Los Angeles
# 37231                           MAGNA HUB INC       Los Angeles
#
#           home_base_state        carrier_trucks  num_trucks  \
# id_driver
# 33                     CA            ["dryvan"]         1.0
# 38                     CA            ["dryvan"]         1.0
# 41                     CA         ["poweronly"]         1.0
# 154                    CA            ["dryvan"]         1.0
# 329                    CA  ["dryvan", "reefer"]        17.0
# ...                   ...                   ...         ...
# 35581                  CA         ["poweronly"]         1.0
# 36275                  CA         ["poweronly"]         1.0
# 36637                  CA         ["poweronly"]         2.0
# 36717                  CA         ["poweronly"]         4.0
# 37231                  CA         ["poweronly"]         1.0
#
#           interested_in_drayage  ... first_load_date most_recent_load_date  \
# id_driver                        ...
# 33                not specified  ...      2015-10-14            2017-12-14
# 38                not specified  ...      2015-10-19            2017-12-14
# 41                not specified  ...      2015-10-21            2019-11-08
# 154                         yes  ...      2015-10-04            2017-12-14
# 329               not specified  ...      2016-02-02            2019-01-03
# ...                         ...  ...             ...                   ...
# 35581                       yes  ...      2020-10-16            2021-02-17
# 36275                       yes  ...      2020-10-04            2021-02-17
# 36637                       yes  ...      2020-10-31            2021-02-17
# 36717                       yes  ...      2020-11-05            2021-02-17
# 37231                       yes  ...      2020-12-11            2021-02-11
#
#           loads marketplace_loads_otr  marketplace_loads_atlas  \
# id_driver
# 33            5                     0                        0
# 38            5                     0                        0
# 41            2                    46                        6
# 154           7                     1                        0
# 329           1                    21                        0
# ...         ...                   ...                      ...
# 35581         9                     0                      369
# 36275         7                     0                      387
# 36637         4                     0                      331
# 36717         8                     0                      307
# 37231         5                     0                        0
#
#           marketplace_loads  brokerage_loads_otr brokerage_loads_atlas  \
# id_driver
# 33                        0                  669                     0
# 38                        0                  656                     0
# 41                       52                  425                     0
# 154                       1                 1292                     0
# 329                      21                  338                     0
# ...                     ...                  ...                   ...
# 35581                   369                    0                    44
# 36275                   387                    0                   145
# 36637                   331                    0                    12
# 36717                   307                    0                    21
# 37231                     0                    0                   350
#
#           brokerage_loads  total_loads
# id_driver
# 33                    669          669
# 38                    656          656
# 41                    425          477
# 154                  1292         1293
# 329                   338          359
# ...                   ...          ...
# 35581                  44          413
# 36275                 145          532
# 36637                  12          343
# 36717                  21          328
# 37231                 350          350
#
# [99 rows x 27 columns]

# %% [markdown]
# ### Option 2&1 (requires collapsing again)

# %%
top_loads = driver_most_recent.total_loads.quantile(0.75)
top_most_recent = df.most_recent_load_date.quantile(0.75)
top = df[(driver_most_recent.total_loads >= top_loads) & (df.most_recent_load_date >= top_most_recent)]
top = top.groupby('id_driver').agg('max')
top
# Out:
#                   dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 3721      2020-09-09        3          U0093573   Owner Operator
# 3851      2020-01-13        5          U0093691   Owner Operator
# 4516      2020-12-02        4          C0090399            Fleet
# 4524      2021-02-03        5          C0090405            Fleet
# 6223      2020-10-01        4          U0095596   Owner Operator
# ...              ...      ...               ...              ...
# 37534     2021-02-11        4          C0098627            Fleet
# 37589     2021-01-31        7          C0098704            Fleet
# 37596     2021-02-03        3          C0094651            Fleet
# 37626     2021-02-03        3          C0094651            Fleet
# 37811     2021-02-02        2          C0098487            Fleet
#
#           dim_carrier_company_name         home_base_city home_base_state  \
# id_driver
# 3721              Amit carrier inc               La Habra              CA
# 3851              pappy's trucking            Los Angeles              CA
# 4516                   ABF FREIGHT             Fort Smith              AR
# 4524            Daylight Transport             Long Beach              CA
# 6223        XA Torres Delivery LLC                 Perris              CA
# ...                            ...                    ...             ...
# 37534         Curiel transport llc                Anaheim              CA
# 37589        Ibarra Transportation                   Bell              CA
# 37596            NFS asset Drayage                Lynwood              CA
# 37626            NFS asset Drayage                Lynwood              CA
# 37811        Workflow Trucking LLC  San Bernardino County              CA
#
#                     carrier_trucks  num_trucks interested_in_drayage  ...  \
# id_driver                                                             ...
# 3721                    ["dryvan"]         1.0         not specified  ...
# 3851                    ["dryvan"]         1.0         not specified  ...
# 4516                    ["dryvan"]         2.0         not specified  ...
# 4524                    ["dryvan"]         6.0         not specified  ...
# 6223                    ["dryvan"]         1.0         not specified  ...
# ...                            ...         ...                   ...  ...
# 37534                ["poweronly"]        15.0         not specified  ...
# 37589                ["poweronly"]         3.0                   yes  ...
# 37596      ["poweronly", "dryvan"]       195.0                   yes  ...
# 37626      ["poweronly", "dryvan"]       195.0                   yes  ...
# 37811      ["dryvan", "poweronly"]         3.0         not specified  ...
#
#           first_load_date most_recent_load_date loads marketplace_loads_otr  \
# id_driver
# 3721           2019-05-14            2021-02-16     1                     9
# 3851           2017-06-27            2021-02-17     1                   286
# 4516           2018-07-31            2021-02-16    10                     0
# 4524           2017-01-20            2021-02-15     7                     0
# 6223           2017-05-02            2021-02-17     1                    12
# ...                   ...                   ...   ...                   ...
# 37534          2021-01-14            2021-02-16     2                     4
# 37589          2021-01-14            2021-02-17     2                     0
# 37596          2021-01-14            2021-02-17     1                     0
# 37626          2021-01-18            2021-02-17     3                     0
# 37811          2021-01-28            2021-02-17     1                     0
#
#            marketplace_loads_atlas marketplace_loads brokerage_loads_otr  \
# id_driver
# 3721                            61                70                   0
# 3851                             4               290                 226
# 4516                             0                 0                1255
# 4524                             0                 0                2671
# 6223                             0                12                 155
# ...                            ...               ...                 ...
# 37534                           28                32                   0
# 37589                           67                67                   0
# 37596                            0                 0                   0
# 37626                            0                 0                   0
# 37811                            0                 0                  16
#
#           brokerage_loads_atlas brokerage_loads  total_loads
# id_driver
# 3721                          2               2           72
# 3851                          0             226          516
# 4516                          0            1255         1255
# 4524                          0            2671         2671
# 6223                          0             155          167
# ...                         ...             ...          ...
# 37534                         0               0           32
# 37589                         1               1           68
# 37596                         0               0           41
# 37626                         0               0           31
# 37811                         0              16           16
#
# [163 rows x 27 columns]

# %% [markdown]
# ### Option 2&2 (already collapsed)

# %%
top_loads = driver_most_recent.total_loads.quantile(0.75)
top_most_recent = driver_most_recent.most_recent_load_date.quantile(0.75)
top = driver_most_recent[(driver_most_recent.total_loads >= top_loads) & (driver_most_recent.most_recent_load_date >= top_most_recent)]
top
# Out:
#                   dt  weekday id_carrier_number dim_carrier_type  \
# id_driver
# 50        2021-02-04        7          U0000068   Owner Operator
# 594       2020-09-07        7          C0090094            Fleet
# 613       2020-06-24        6          C0090094            Fleet
# 614       2020-06-27        7          C0090094            Fleet
# 629       2020-07-22        6          C0090094            Fleet
# ...              ...      ...               ...              ...
# 37860     2021-02-12        6          C0098263            Fleet
# 37862     2021-02-17        7          C0098794            Fleet
# 37863     2021-02-17        6          C0094651            Fleet
# 37901     2021-02-11        5          C0098808            Fleet
# 37936     2021-02-17        7          U0124035   Owner Operator
#
#           dim_carrier_company_name home_base_city home_base_state  \
# id_driver
# 50                    DOMINGO OREA         Covina              CA
# 594        MC Express Trucking LLC       Rosarito            B.C.
# 613        MC Express Trucking LLC       Rosarito            B.C.
# 614        MC Express Trucking LLC       Rosarito            B.C.
# 629        MC Express Trucking LLC       Rosarito            B.C.
# ...                            ...            ...             ...
# 37860              EAX EXPRESS INC        Fontana              CA
# 37862                R W L EXPRESS     Long Beach              CA
# 37863            NFS asset Drayage        Lynwood              CA
# 37901             Ynot Express LLC      Hawthorne              CA
# 37936        DT Transportation Inc  Jurupa Valley              CA
#
#                     carrier_trucks  num_trucks interested_in_drayage  ...  \
# id_driver                                                             ...
# 50                   ["poweronly"]         1.0                   yes  ...
# 594                     ["dryvan"]       101.0         not specified  ...
# 613                     ["dryvan"]       101.0         not specified  ...
# 614                     ["dryvan"]       101.0         not specified  ...
# 629                     ["dryvan"]       101.0         not specified  ...
# ...                            ...         ...                   ...  ...
# 37860                ["poweronly"]         6.0         not specified  ...
# 37862      ["dryvan", "poweronly"]         2.0                   yes  ...
# 37863      ["poweronly", "dryvan"]       195.0                   yes  ...
# 37901                ["poweronly"]         2.0                   yes  ...
# 37936                ["poweronly"]         1.0                   yes  ...
#
#           first_load_date most_recent_load_date loads marketplace_loads_otr  \
# id_driver
# 50             2015-12-09            2021-02-04     8                     0
# 594            2016-04-05            2020-09-07    29                     0
# 613            2016-03-15            2020-06-24     3                     0
# 614            2016-04-05            2020-06-27     2                     0
# 629            2016-04-26            2020-07-22     4                     0
# ...                   ...                   ...   ...                   ...
# 37860          2021-01-30            2021-02-12     4                     0
# 37862          2021-01-31            2021-02-17     3                     0
# 37863          2021-02-08            2021-02-17     4                     0
# 37901          2021-02-02            2021-02-11     8                     0
# 37936          2021-02-05            2021-02-17     6                     0
#
#            marketplace_loads_atlas marketplace_loads brokerage_loads_otr  \
# id_driver
# 50                             425               425                  10
# 594                              0                 0                1309
# 613                              0                 0                 110
# 614                              0                 0                  66
# 629                              0                 0                  32
# ...                            ...               ...                 ...
# 37860                            1                 1                   0
# 37862                           17                17                   0
# 37863                            0                 0                   0
# 37901                           31                31                   0
# 37936                           35                35                   0
#
#           brokerage_loads_atlas brokerage_loads  total_loads
# id_driver
# 50                           69              79          504
# 594                           0            1309         1309
# 613                           0             110          110
# 614                           0              66           66
# 629                           0              32           32
# ...                         ...             ...          ...
# 37860                        17              17           18
# 37862                         4               4           21
# 37863                         0               0           18
# 37901                         2               2           33
# 37936                         2               2           37
#
# [707 rows x 27 columns]
